# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r"C:\Users\SWAROOP\Desktop\Ecommerce.csv")

# Display the first few rows of the dataset
print("First 5 rows of the dataset:")
print(df.head())

# Display basic information about the dataset
print("\nDataset Info:")
print(df.info())

# Statistical summary of numerical columns
print("\nStatistical Summary (Numerical Columns):")
print(df.describe())

# Check for missing values
print("\nMissing Values in Each Column:")
print(df.isnull().sum())

# Visualizing missing values using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# Univariate Analysis - Histogram of numerical columns
df.hist(bins=30, figsize=(15, 10), edgecolor='black')
plt.suptitle("Histograms of Numerical Columns", fontsize=16)
plt.show()

# Univariate Analysis - Boxplot for numerical features to detect outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['Age', 'Annual_Income', 'Spending_Score', 'Products_Purchased', 'Last_Purchase_Amount']])
plt.title("Boxplot of Numerical Features")
plt.xticks(rotation=90)
plt.show()

# Pairplot to explore relationships between numerical features
sns.pairplot(df[['Age', 'Annual_Income', 'Spending_Score', 'Products_Purchased', 'Last_Purchase_Amount']])
plt.suptitle("Pairplot for Relationships between Numerical Features", y=1.02)
plt.show()

# Correlation heatmap for numerical columns
plt.figure(figsize=(10, 8))
corr_matrix = df[['Age', 'Annual_Income', 'Spending_Score', 'Products_Purchased', 'Last_Purchase_Amount']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# Count plot for 'Gender'
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=df)
plt.title("Count Plot for Gender")
plt.show()

# Count plot for 'Membership_Level'
plt.figure(figsize=(8, 6))
sns.countplot(x='Membership_Level', data=df, palette='Set2')
plt.title("Count Plot for Membership Level")
plt.show()

# Visualizing the relationship between Age and Spending Score
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Spending_Score', hue='Gender', data=df)
plt.title("Age vs Spending Score by Gender")
plt.show()

# Visualizing the relationship between Annual Income and Spending Score
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Annual_Income', y='Spending_Score', hue='Membership_Level', palette='cool', data=df)
plt.title("Annual Income vs Spending Score by Membership Level")
plt.show()
# Out:
# First 5 rows of the dataset:
#    CustomerID           Name   Age  Gender  Annual_Income  Spending_Score  \
# 0        1001     John Smith  25.0    Male          45000              78
# 1        1002       Sara Lee  34.0  Female          52000              45
# 2        1003  Michael Brown  29.0    Male          60000              32
# 3        1004    Linda Green   NaN  Female          75000              70
# 4        1005    James White  31.0    Male          58000              50
#
#   Membership_Level  Products_Purchased  Last_Purchase_Amount
# 0             Gold                 5.0                   150
# 1           Silver                 3.0                    80
# 2           Bronze                 2.0                   120
# 3             Gold                 7.0                   200
# 4           Silver                 4.0                   110
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
# ...
